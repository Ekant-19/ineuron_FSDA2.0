# %%
pip install -U typing_extensions
# Out:
# Requirement already satisfied: typing_extensions in c:\users\ekant\anaconda3\lib\site-packages (4.5.0)
# Collecting typing_extensions
#   Downloading typing_extensions-4.6.3-py3-none-any.whl (31 kB)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.5.0
#     Uninstalling typing-extensions-4.5.0:
#       Successfully uninstalled typing-extensions-4.5.0
# Successfully installed typing-extensions-4.6.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install snowflake-connector-python
# Out:
# Requirement already satisfied: snowflake-connector-python in c:\users\ekant\anaconda3\lib\site-packages (3.0.3)
# Requirement already satisfied: requests<3.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (2.27.1)
# Requirement already satisfied: typing-extensions<5,>=4.3 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (2023.5.7)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (1.15.0)
# Requirement already satisfied: filelock<4,>=3.5 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (3.6.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: cryptography<41.0.0,>=3.1.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (3.4.8)
# Requirement already satisfied: oscrypto<2.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (1.3.0)
# Requirement already satisfied: packaging in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (21.3)
# Requirement already satisfied: pytz in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (2021.3)
# Requirement already satisfied: pyOpenSSL<24.0.0,>=16.2.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (21.0.0)
# Requirement already satisfied: pycryptodomex!=3.5.0,<4.0.0,>=3.2 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (3.17)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (2.0.4)
# Requirement already satisfied: pyjwt<3.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python) (2.1.0)
# Requirement already satisfied: pycparser in c:\users\ekant\anaconda3\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.21)
# Requirement already satisfied: six>=1.5.2 in c:\users\ekant\anaconda3\lib\site-packages (from pyOpenSSL<24.0.0,>=16.2.0->snowflake-connector-python) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ekant\anaconda3\lib\site-packages (from packaging->snowflake-connector-python) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install snowflake-sqlalchemy
# Out:
# Requirement already satisfied: snowflake-sqlalchemy in c:\users\ekant\anaconda3\lib\site-packages (1.4.7)
# Requirement already satisfied: sqlalchemy<2.0.0,>=1.4.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-sqlalchemy) (1.4.32)
# Requirement already satisfied: snowflake-connector-python<4.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-sqlalchemy) (3.0.3)
# Requirement already satisfied: typing-extensions<5,>=4.3 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (4.5.0)
# Requirement already satisfied: pyOpenSSL<24.0.0,>=16.2.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (21.0.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.3)
# Requirement already satisfied: filelock<4,>=3.5 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.6.0)
# Requirement already satisfied: cryptography<41.0.0,>=3.1.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.4.8)
# Requirement already satisfied: pycryptodomex!=3.5.0,<4.0.0,>=3.2 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.17)
# Requirement already satisfied: oscrypto<2.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (1.3.0)
# Requirement already satisfied: pyjwt<3.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.1.0)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (1.15.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (1.5.1)
# Requirement already satisfied: packaging in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (21.3)
# Requirement already satisfied: pytz in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2021.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (1.26.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2023.5.7)
# Requirement already satisfied: requests<3.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.27.1)
# Requirement already satisfied: pycparser in c:\users\ekant\anaconda3\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.21)
# Requirement already satisfied: six>=1.5.2 in c:\users\ekant\anaconda3\lib\site-packages (from pyOpenSSL<24.0.0,>=16.2.0->snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ekant\anaconda3\lib\site-packages (from sqlalchemy<2.0.0,>=1.4.0->snowflake-sqlalchemy) (1.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ekant\anaconda3\lib\site-packages (from packaging->snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "snowflake-connector-python[pandas]"
# Out:
# Requirement already satisfied: snowflake-connector-python[pandas] in c:\users\ekant\anaconda3\lib\site-packages (3.0.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: cffi<2.0.0,>=1.9 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (3.3)
# Requirement already satisfied: pyjwt<3.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (2.1.0)
# Requirement already satisfied: pytz in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (2021.3)
# Requirement already satisfied: pycryptodomex!=3.5.0,<4.0.0,>=3.2 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (3.17)
# Requirement already satisfied: oscrypto<2.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (2023.5.7)
# Requirement already satisfied: filelock<4,>=3.5 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (3.6.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (2.0.4)
# Requirement already satisfied: requests<3.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (1.26.9)
# Requirement already satisfied: cryptography<41.0.0,>=3.1.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (3.4.8)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (1.5.1)
# Requirement already satisfied: typing-extensions<5,>=4.3 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (4.5.0)
# Requirement already satisfied: packaging in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (21.3)
# Requirement already satisfied: pyOpenSSL<24.0.0,>=16.2.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (21.0.0)
# Requirement already satisfied: pyarrow<10.1.0,>=10.0.1 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (10.0.1)
# Requirement already satisfied: pandas<1.6.0,>=1.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from snowflake-connector-python[pandas]) (1.5.2)
# Requirement already satisfied: pycparser in c:\users\ekant\anaconda3\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python[pandas]) (2.21)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\ekant\anaconda3\lib\site-packages (from pandas<1.6.0,>=1.0.0->snowflake-connector-python[pandas]) (1.23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ekant\anaconda3\lib\site-packages (from pandas<1.6.0,>=1.0.0->snowflake-connector-python[pandas]) (2.8.2)
# Requirement already satisfied: six>=1.5.2 in c:\users\ekant\anaconda3\lib\site-packages (from pyOpenSSL<24.0.0,>=16.2.0->snowflake-connector-python[pandas]) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ekant\anaconda3\lib\site-packages (from packaging->snowflake-connector-python[pandas]) (3.0.4)

# %%
pip install jupyter_scheduler
# Out:
# Requirement already satisfied: jupyter_scheduler in c:\users\ekant\anaconda3\lib\site-packages (1.3.2)
# Requirement already satisfied: pydantic in c:\users\ekant\anaconda3\lib\site-packages (from jupyter_scheduler) (1.10.2)
# Requirement already satisfied: croniter in c:\users\ekant\anaconda3\lib\site-packages (from jupyter_scheduler) (1.3.15)
# Requirement already satisfied: fsspec in c:\users\ekant\anaconda3\lib\site-packages (from jupyter_scheduler) (2023.5.0)
# Requirement already satisfied: sqlalchemy<2 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter_scheduler) (1.4.32)
# Requirement already satisfied: psutil in c:\users\ekant\anaconda3\lib\site-packages (from jupyter_scheduler) (5.8.0)
# Requirement already satisfied: traitlets in c:\users\ekant\anaconda3\lib\site-packages (from jupyter_scheduler) (5.1.1)
# Requirement already satisfied: nbconvert in c:\users\ekant\anaconda3\lib\site-packages (from jupyter_scheduler) (6.4.4)
# Requirement already satisfied: jupyter-server<3,>=1.6 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter_scheduler) (1.23.4)
# Requirement already satisfied: pytz in c:\users\ekant\anaconda3\lib\site-packages (from jupyter_scheduler) (2021.3)
# Requirement already satisfied: s3fs in c:\users\ekant\anaconda3\lib\site-packages (from jupyter_scheduler) (2023.5.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (22.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (6.1.12)
# Requirement already satisfied: nbformat>=5.2.0 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (5.3.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (3.5.0)
# Requirement already satisfied: Send2Trash in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (1.8.0)
# Requirement already satisfied: jinja2 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (2.11.3)
# Requirement already satisfied: packaging in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (21.3)
# Requirement already satisfied: pywinpty in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (2.0.10)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (0.13.1)
# Requirement already satisfied: websocket-client in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (0.58.0)
# Requirement already satisfied: argon2-cffi in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.7.0 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (4.9.2)
# Requirement already satisfied: prometheus-client in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (0.13.1)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (6.1)
# Requirement already satisfied: idna>=2.8 in c:\users\ekant\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.6->jupyter_scheduler) (3.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ekant\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.6->jupyter_scheduler) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server<3,>=1.6->jupyter_scheduler) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-core>=4.7.0->jupyter-server<3,>=1.6->jupyter_scheduler) (302)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert->jupyter_scheduler) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert->jupyter_scheduler) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert->jupyter_scheduler) (0.4)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert->jupyter_scheduler) (2.11.2)
# Requirement already satisfied: testpath in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert->jupyter_scheduler) (0.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert->jupyter_scheduler) (4.11.1)
# Requirement already satisfied: bleach in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert->jupyter_scheduler) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert->jupyter_scheduler) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert->jupyter_scheduler) (0.5.13)
# Requirement already satisfied: defusedxml in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert->jupyter_scheduler) (0.7.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ekant\anaconda3\lib\site-packages (from jinja2->jupyter-server<3,>=1.6->jupyter_scheduler) (2.0.1)
# Requirement already satisfied: nest-asyncio in c:\users\ekant\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter_scheduler) (1.5.5)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\ekant\anaconda3\lib\site-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.6->jupyter_scheduler) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\ekant\anaconda3\lib\site-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.6->jupyter_scheduler) (2.15.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ekant\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server<3,>=1.6->jupyter_scheduler) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ekant\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server<3,>=1.6->jupyter_scheduler) (21.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\ekant\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client>=6.1.12->jupyter-server<3,>=1.6->jupyter_scheduler) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ekant\anaconda3\lib\site-packages (from sqlalchemy<2->jupyter_scheduler) (1.1.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ekant\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=1.6->jupyter_scheduler) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ekant\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.6->jupyter_scheduler) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\ekant\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.6->jupyter_scheduler) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ekant\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter_scheduler) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\ekant\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter_scheduler) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ekant\anaconda3\lib\site-packages (from packaging->jupyter-server<3,>=1.6->jupyter_scheduler) (3.0.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\ekant\anaconda3\lib\site-packages (from pydantic->jupyter_scheduler) (4.5.0)
# Requirement already satisfied: aiobotocore~=2.5.0 in c:\users\ekant\anaconda3\lib\site-packages (from s3fs->jupyter_scheduler) (2.5.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\ekant\anaconda3\lib\site-packages (from s3fs->jupyter_scheduler) (3.8.1)
# Requirement already satisfied: aioitertools>=0.5.1 in c:\users\ekant\anaconda3\lib\site-packages (from aiobotocore~=2.5.0->s3fs->jupyter_scheduler) (0.11.0)
# Requirement already satisfied: wrapt>=1.10.10 in c:\users\ekant\anaconda3\lib\site-packages (from aiobotocore~=2.5.0->s3fs->jupyter_scheduler) (1.12.1)
# Requirement already satisfied: botocore<1.29.77,>=1.29.76 in c:\users\ekant\anaconda3\lib\site-packages (from aiobotocore~=2.5.0->s3fs->jupyter_scheduler) (1.29.76)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ekant\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->jupyter_scheduler) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ekant\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->jupyter_scheduler) (1.6.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ekant\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->jupyter_scheduler) (5.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\ekant\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->jupyter_scheduler) (2.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\ekant\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->jupyter_scheduler) (4.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ekant\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->jupyter_scheduler) (1.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\ekant\anaconda3\lib\site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs->jupyter_scheduler) (1.26.9)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\ekant\anaconda3\lib\site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs->jupyter_scheduler) (0.10.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyterlab-scheduler
# Out:
# Requirement already satisfied: jupyterlab-scheduler in c:\users\ekant\anaconda3\lib\site-packages (0.1.5)
# Requirement already satisfied: python-crontab~=2.5 in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab-scheduler) (2.7.1)
# Requirement already satisfied: papermill~=2.1 in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab-scheduler) (2.4.0)
# Requirement already satisfied: jupyterlab~=3.1.4 in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab-scheduler) (3.1.19)
# Requirement already satisfied: jupyter-core in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (4.9.2)
# Requirement already satisfied: jupyter-server~=1.4 in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (1.23.4)
# Requirement already satisfied: jinja2>=2.1 in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (2.11.3)
# Requirement already satisfied: jupyterlab-server~=2.3 in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (2.10.3)
# Requirement already satisfied: nbclassic~=0.2 in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (0.3.5)
# Requirement already satisfied: ipython in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (8.2.0)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (6.1)
# Requirement already satisfied: packaging in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab~=3.1.4->jupyterlab-scheduler) (21.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ekant\anaconda3\lib\site-packages (from jinja2>=2.1->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.0.1)
# Requirement already satisfied: argon2-cffi in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (21.3.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (3.5.0)
# Requirement already satisfied: traitlets>=5.1 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (5.1.1)
# Requirement already satisfied: nbformat>=5.2.0 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (5.3.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (22.3.0)
# Requirement already satisfied: Send2Trash in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (6.1.12)
# Requirement already satisfied: prometheus-client in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.13.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.13.1)
# Requirement already satisfied: pywinpty in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.0.10)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (6.4.4)
# Requirement already satisfied: websocket-client in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.58.0)
# Requirement already satisfied: idna>=2.8 in c:\users\ekant\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (3.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ekant\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ekant\anaconda3\lib\site-packages (from jupyter-core->jupyterlab~=3.1.4->jupyterlab-scheduler) (302)
# Requirement already satisfied: babel in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.9.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.4)
# Requirement already satisfied: json5 in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.9.6)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (4.4.0)
# Requirement already satisfied: requests in c:\users\ekant\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.27.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ekant\anaconda3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ekant\anaconda3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (21.4.0)
# Requirement already satisfied: notebook<7 in c:\users\ekant\anaconda3\lib\site-packages (from nbclassic~=0.2->jupyterlab~=3.1.4->jupyterlab-scheduler) (6.4.8)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.11.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (4.11.1)
# Requirement already satisfied: defusedxml in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.1.2)
# Requirement already satisfied: testpath in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.5.0)
# Requirement already satisfied: bleach in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ekant\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.8.4)
# Requirement already satisfied: nest-asyncio in c:\users\ekant\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.5.5)
# Requirement already satisfied: fastjsonschema in c:\users\ekant\anaconda3\lib\site-packages (from nbformat>=5.2.0->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.15.1)
# Requirement already satisfied: ipython-genutils in c:\users\ekant\anaconda3\lib\site-packages (from notebook<7->nbclassic~=0.2->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.2.0)
# Requirement already satisfied: ipykernel in c:\users\ekant\anaconda3\lib\site-packages (from notebook<7->nbclassic~=0.2->jupyterlab~=3.1.4->jupyterlab-scheduler) (6.9.1)
# Requirement already satisfied: pyyaml in c:\users\ekant\anaconda3\lib\site-packages (from papermill~=2.1->jupyterlab-scheduler) (6.0)
# Requirement already satisfied: tqdm>=4.32.2 in c:\users\ekant\anaconda3\lib\site-packages (from papermill~=2.1->jupyterlab-scheduler) (4.64.0)
# Requirement already satisfied: tenacity in c:\users\ekant\anaconda3\lib\site-packages (from papermill~=2.1->jupyterlab-scheduler) (8.0.1)
# Requirement already satisfied: click in c:\users\ekant\anaconda3\lib\site-packages (from papermill~=2.1->jupyterlab-scheduler) (8.0.4)
# Requirement already satisfied: ansiwrap in c:\users\ekant\anaconda3\lib\site-packages (from papermill~=2.1->jupyterlab-scheduler) (0.8.4)
# Requirement already satisfied: six>=1.5 in c:\users\ekant\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client>=6.1.12->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.16.0)
# Requirement already satisfied: colorama in c:\users\ekant\anaconda3\lib\site-packages (from tqdm>=4.32.2->papermill~=2.1->jupyterlab-scheduler) (0.4.4)
# Requirement already satisfied: textwrap3>=0.9.2 in c:\users\ekant\anaconda3\lib\site-packages (from ansiwrap->papermill~=2.1->jupyterlab-scheduler) (0.9.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ekant\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ekant\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\ekant\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.21)
# Requirement already satisfied: pytz>=2015.7 in c:\users\ekant\anaconda3\lib\site-packages (from babel->jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (2021.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ekant\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\ekant\anaconda3\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server~=1.4->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\ekant\anaconda3\lib\site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.5.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ekant\anaconda3\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (61.2.0)
# Requirement already satisfied: stack-data in c:\users\ekant\anaconda3\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.2.0)
# Requirement already satisfied: backcall in c:\users\ekant\anaconda3\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (3.0.20)
# Requirement already satisfied: decorator in c:\users\ekant\anaconda3\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ekant\anaconda3\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\ekant\anaconda3\lib\site-packages (from ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ekant\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\ekant\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ekant\anaconda3\lib\site-packages (from packaging->jupyterlab~=3.1.4->jupyterlab-scheduler) (3.0.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ekant\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ekant\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.3->jupyterlab~=3.1.4->jupyterlab-scheduler) (1.26.9)
# Requirement already satisfied: executing in c:\users\ekant\anaconda3\lib\site-packages (from stack-data->ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\ekant\anaconda3\lib\site-packages (from stack-data->ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ekant\anaconda3\lib\site-packages (from stack-data->ipython->jupyterlab~=3.1.4->jupyterlab-scheduler) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import snowflake.connector

# %%
pip install pandas_profiling
# Out:
# Requirement already satisfied: pandas_profiling in c:\users\ekant\anaconda3\lib\site-packages (3.6.6)
# Requirement already satisfied: ydata-profiling in c:\users\ekant\anaconda3\lib\site-packages (from pandas_profiling) (4.0.0)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (3.6.0)
# Requirement already satisfied: requests<2.29,>=2.24.0 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (2.27.1)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (6.0)
# Requirement already satisfied: multimethod<1.10,>=1.4 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.9.1)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.10.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (2.11.3)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (0.1.12)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (4.64.0)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (2.13.3)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (0.13.2)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.23.1)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (0.7.5)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (0.12.3)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.9.3)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (0.11.2)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in c:\users\ekant\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.5.2)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\ekant\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (0.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\ekant\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (2.7.1)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\ekant\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (21.4.0)
# Requirement already satisfied: Pillow in c:\users\ekant\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (9.0.1)
# Requirement already satisfied: imagehash in c:\users\ekant\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (4.3.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ekant\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas_profiling) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ekant\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling) (1.0.7)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ekant\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ekant\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ekant\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ekant\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ekant\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ekant\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ekant\anaconda3\lib\site-packages (from pandas!=1.4.0,<1.6,>1.1->ydata-profiling->pandas_profiling) (2021.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\ekant\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas_profiling) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\ekant\anaconda3\lib\site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling->pandas_profiling) (4.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\ekant\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.7,>=3.2->ydata-profiling->pandas_profiling) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ekant\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas_profiling) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ekant\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas_profiling) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ekant\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas_profiling) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ekant\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas_profiling) (2.0.4)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\ekant\anaconda3\lib\site-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling->pandas_profiling) (0.5.2)
# Requirement already satisfied: colorama in c:\users\ekant\anaconda3\lib\site-packages (from tqdm<4.65,>=4.48.2->ydata-profiling->pandas_profiling) (0.4.4)
# Requirement already satisfied: PyWavelets in c:\users\ekant\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np 
import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt
# %matplotlib inline
##import getpass
# Out:
# C:\Users\EKANT\AppData\Local\Temp\ipykernel_7172\1592052299.py:3: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %%
import snowflake.connector

# %%
account = 'bcfkzvf-rd27110'        
user = 'EKANT02'
password = 'Akant@1901'
database = 'Retail'
schema = 'PUBLIC'
warehouse = 'COMPUTE_WH'

# %%
conn = snowflake.connector.connect(
    user=user,
    password=password,
    ## password = getpass.getpass("Your snowflake password")
    account=account,
    database=database,
    schema=schema,
    warehouse=warehouse
)

# %%
cur = conn.cursor()

# %%
cur.execute("SELECT * FROM DEMOGRAPHIC_RAW")

# %%
DEMOGRAPHIC_RAW = cur.fetch_pandas_all()

# %%
DEMOGRAPHIC_RAW.head(10)
# Out:
#   AGE_DESC MARITAL_STATUS_CODE INCOME_DESC HOMEOWNER_DESC      HH_COMP_DESC  \
# 0      65+                   A      35-49K      Homeowner  2 Adults No Kids
# 1    45-54                   A      50-74K      Homeowner  2 Adults No Kids
# 2    25-34                   U      25-34K        Unknown     2 Adults Kids
# 3    25-34                   U      75-99K      Homeowner     2 Adults Kids
# 4    45-54                   B      50-74K      Homeowner     Single Female
# 5      65+                   B   Under 15K      Homeowner  2 Adults No Kids
# 6    45-54                   A    100-124K      Homeowner  2 Adults No Kids
# 7    35-44                   B      15-24K        Unknown     Single Female
# 8    25-34                   A      75-99K         Renter  2 Adults No Kids
# 9    45-54                   A      75-99K      Homeowner  2 Adults No Kids
#
#   HOUSEHOLD_SIZE_DESC KID_CATEGORY_DESC  HOUSEHOLD_KEY
# 0                   2      None/Unknown              1
# 1                   2      None/Unknown              7
# 2                   3                 1              8
# 3                   4                 2             13
# 4                   1      None/Unknown             16
# 5                   2      None/Unknown             17
# 6                   2      None/Unknown             18
# 7                   1      None/Unknown             19
# 8                   2      None/Unknown             20
# 9                   2      None/Unknown             22

# %%
cur.execute("SELECT * FROM CAMPAIGN_DESC_RAW")

# %%
CAMPAIGN_DESC_RAW = cur.fetch_pandas_all()
CAMPAIGN_DESC_RAW.head(10)
# Out:
#   DESCRIPTION  CAMPAIGN  START_DAY  END_DAY
# 0       TypeB        24        659      719
# 1       TypeC        15        547      708
# 2       TypeB        25        659      691
# 3       TypeC        20        615      685
# 4       TypeB        23        646      684
# 5       TypeB        21        624      656
# 6       TypeB        22        624      656
# 7       TypeA        18        587      642
# 8       TypeB        19        603      635
# 9       TypeB        17        575      607

# %%
cur.execute("SELECT * FROM COUPON_REDEMPT_RAW")
COUPON_REDEMPT_RAW = cur.fetch_pandas_all()
COUPON_REDEMPT_RAW.head(10)
# Out:
#    HOUSEHOLD_KEY  DAY   COUPON_UPC  CAMPAIGN
# 0              1  421  10000085364         8
# 1              1  421  51700010076         8
# 2              1  427  54200000033         8
# 3              1  597  10000085476        18
# 4              1  597  54200029176        18
# 5              8  422  53600000078         8
# 6             13  396  53700048182         5
# 7             13  424  10000085364         8
# 8             13  434  53600000078         8
# 9             13  447  52370020076         8

# %%
cur.execute("SELECT * FROM PRODUCT_RAW")
PRODUCT_RAW = cur.fetch_pandas_all()
PRODUCT_RAW.head(10)
# Out:
#    PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND            COMMODITY_DESC  \
# 0       25671             2       GROCERY  National                  FRZN ICE
# 1       26081             2  MISC. TRANS.  National  NO COMMODITY DESCRIPTION
# 2       26093            69        PASTRY   Private                     BREAD
# 3       26190            69       GROCERY   Private      FRUIT - SHELF STABLE
# 4       26355            69       GROCERY   Private             COOKIES/CONES
# 5       26426            69       GROCERY   Private         SPICES & EXTRACTS
# 6       26540            69       GROCERY   Private             COOKIES/CONES
# 7       26601            69       DRUG GM   Private                  VITAMINS
# 8       26636            69        PASTRY   Private          BREAKFAST SWEETS
# 9       26691            16       GROCERY   Private        PNT BTR/JELLY/JAMS
#
#             SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 0          ICE - CRUSHED/CUBED                22 LB
# 1  NO SUBCOMMODITY DESCRIPTION
# 2         BREAD:ITALIAN/FRENCH
# 3                  APPLE SAUCE                50 OZ
# 4            SPECIALTY COOKIES                14 OZ
# 5          SPICES & SEASONINGS               2.5 OZ
# 6  TRAY PACK/CHOC CHIP COOKIES                16 OZ
# 7           VITAMIN - MINERALS             300CT(1)
# 8         SW GDS: SW ROLLS/DAN
# 9                        HONEY                12 OZ

# %%
cur.execute("SELECT * FROM COUPON_RAW")
COUPON_RAW = cur.fetch_pandas_all()
COUPON_RAW.head(10)
# Out:
#     COUPON_UPC  PRODUCT_ID  CAMPAIGN
# 0  10000089061       27160         4
# 1  10000089064       27754         9
# 2  10000089073       28897        12
# 3  51800009050       28919        28
# 4  52100000076       28929        25
# 5  52100000031       28929        22
# 6  52100000033       28929         9
# 7  52100026076       28929        28
# 8  52100020075       28929         1
# 9  52100000076       29096        25

# %%
cur.execute("SELECT * FROM COUPON_REDEMPT_RAW")
COUPON_REDEMPT_RAW = cur.fetch_pandas_all()
COUPON_REDEMPT_RAW.head(10)
# Out:
#    HOUSEHOLD_KEY  DAY   COUPON_UPC  CAMPAIGN
# 0              1  421  10000085364         8
# 1              1  421  51700010076         8
# 2              1  427  54200000033         8
# 3              1  597  10000085476        18
# 4              1  597  54200029176        18
# 5              8  422  53600000078         8
# 6             13  396  53700048182         5
# 7             13  424  10000085364         8
# 8             13  434  53600000078         8
# 9             13  447  52370020076         8

# %%
cur.execute("SELECT * FROM TRANSACTION_RAW")
TRANSACTION_RAW = cur.fetch_pandas_all()
TRANSACTION_RAW.head(10)
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           2375  26984851472    1     1004906         1         1.39
# 1           2375  26984851472    1     1033142         1         0.82
# 2           2375  26984851472    1     1036325         1         0.99
# 3           2375  26984851472    1     1082185         1         1.21
# 4           2375  26984851472    1     8160430         1         1.50
# 5           2375  26984851516    1      826249         2         1.98
# 6           2375  26984851516    1     1043142         1         1.57
# 7           2375  26984851516    1     1085983         1         2.99
# 8           2375  26984851516    1     1102651         1         1.89
# 9           2375  26984851516    1     6423775         1         2.00
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 0       364        -0.60        1631        1            0                  0
# 1       364         0.00        1631        1            0                  0
# 2       364        -0.30        1631        1            0                  0
# 3       364         0.00        1631        1            0                  0
# 4       364        -0.39        1631        1            0                  0
# 5       364        -0.60        1642        1            0                  0
# 6       364        -0.68        1642        1            0                  0
# 7       364        -0.40        1642        1            0                  0
# 8       364         0.00        1642        1            0                  0
# 9       364        -0.79        1642        1            0                  0

# %%
TRANSACTION_RAW.shape
# Out:
# (2595732, 12)

# %%
cur.execute("SELECT * FROM CAMPAIGN_RAW")
CAMPAIGN_RAW = cur.fetch_pandas_all()
CAMPAIGN_RAW.head(10)
# Out:
#   DESCRIPTION  HOUSEHOLD_KEY  CAMPAIGN
# 0       TypeA             17        26
# 1       TypeA             27        26
# 2       TypeA            212        26
# 3       TypeA            208        26
# 4       TypeA            192        26
# 5       TypeA            187        26
# 6       TypeA            183        26
# 7       TypeA            142        26
# 8       TypeA            140        26
# 9       TypeA            134        26

# %%
cur.close()
conn.close()

# %%
CAMPAIGN_RAW.isnull().sum()
# Out:
# DESCRIPTION      0
# HOUSEHOLD_KEY    0
# CAMPAIGN         0
# dtype: int64

# %%
CAMPAIGN_RAW.describe()
# Out:
#        HOUSEHOLD_KEY     CAMPAIGN
# count    7208.000000  7208.000000
# mean     1268.696726    15.659545
# std       731.936391     6.949705
# min         1.000000     1.000000
# 25%       644.000000     9.000000
# 50%      1263.000000    14.000000
# 75%      1924.000000    20.000000
# max      2500.000000    30.000000

# %%
DEMOGRAPHIC_RAW.isnull().sum()
# Out:
# AGE_DESC               0
# MARITAL_STATUS_CODE    0
# INCOME_DESC            0
# HOMEOWNER_DESC         0
# HH_COMP_DESC           0
# HOUSEHOLD_SIZE_DESC    0
# KID_CATEGORY_DESC      0
# HOUSEHOLD_KEY          0
# dtype: int64

# %%
DEMOGRAPHIC_RAW.describe()
# Out:
#        HOUSEHOLD_KEY
# count     2500.00000
# mean      1250.50000
# std        721.83216
# min          1.00000
# 25%        625.75000
# 50%       1250.50000
# 75%       1875.25000
# max       2500.00000

# %%
CAMPAIGN_DESC_RAW.isnull().sum()
# Out:
# DESCRIPTION    0
# CAMPAIGN       0
# START_DAY      0
# END_DAY        0
# dtype: int64

# %%
CAMPAIGN_DESC_RAW.describe()
# Out:
#         CAMPAIGN   START_DAY     END_DAY
# count  30.000000   30.000000   30.000000
# mean   15.500000  463.866667  510.466667
# std     8.803408  134.488490  137.730555
# min     1.000000  224.000000  264.000000
# 25%     8.250000  360.000000  405.750000
# 50%    15.500000  470.000000  502.000000
# 75%    22.750000  584.000000  640.250000
# max    30.000000  659.000000  719.000000

# %%
COUPON_REDEMPT_RAW.isnull().sum()
# Out:
# HOUSEHOLD_KEY    0
# DAY              0
# COUPON_UPC       0
# CAMPAIGN         0
# dtype: int64

# %%
COUPON_REDEMPT_RAW.describe()
# Out:
#        HOUSEHOLD_KEY          DAY    COUPON_UPC     CAMPAIGN
# count    2318.000000  2318.000000  2.318000e+03  2318.000000
# mean     1302.816652   528.217429  4.123049e+10    15.551337
# std       783.002545   100.360985  1.986068e+10     5.716636
# min         1.000000   225.000000  1.000009e+10     1.000000
# 25%       588.000000   458.250000  1.000009e+10    13.000000
# 50%      1396.500000   532.000000  5.234003e+10    14.000000
# 75%      2004.000000   605.000000  5.430002e+10    18.000000
# max      2500.000000   704.000000  5.897850e+10    30.000000

# %%
PRODUCT_RAW.isnull().sum()
# Out:
# PRODUCT_ID              0
# MANUFACTURER            0
# DEPARTMENT              0
# BRAND                   0
# COMMODITY_DESC          0
# SUB_COMMODITY_DESC      0
# CURR_SIZE_OF_PRODUCT    0
# dtype: int64

# %%
PRODUCT_RAW.describe()
# Out:
#          PRODUCT_ID  MANUFACTURER
# count  9.235300e+04   92353.00000
# mean   5.328353e+06    1739.22833
# std    5.359937e+06    1818.26957
# min    2.567100e+04       1.00000
# 25%    9.706280e+05     328.00000
# 50%    1.621091e+06    1094.00000
# 75%    9.704770e+06    2264.00000
# max    1.831630e+07    6477.00000

# %%
COUPON_RAW.isnull().sum()
# Out:
# COUPON_UPC    0
# PRODUCT_ID    0
# CAMPAIGN      0
# dtype: int64

# %%
COUPON_RAW.describe()
# Out:
#          COUPON_UPC    PRODUCT_ID       CAMPAIGN
# count  1.245480e+05  1.245480e+05  124548.000000
# mean   2.198225e+10  4.651277e+06      15.855935
# std    1.961641e+10  4.843450e+06       6.015524
# min    1.000009e+10  2.567100e+04       1.000000
# 25%    1.000009e+10  9.593030e+05      13.000000
# 50%    1.000009e+10  1.411451e+06      14.000000
# 75%    5.111108e+10  8.357538e+06      18.000000
# max    5.998660e+10  1.814854e+07      30.000000

# %% [markdown]
# Date Modified

# %%
from datetime import datetime,timedelta

# %%
start_date = pd.to_datetime('2019-01-01')
start_date
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
TRANSACTION_RAW['Date'] = start_date + pd.to_timedelta(TRANSACTION_RAW['DAY'],unit = 'D')

# %%
TRANSACTION_RAW['Date']
# Out:
# 0         2019-01-02
# 1         2019-01-02
# 2         2019-01-02
# 3         2019-01-02
# 4         2019-01-02
#              ...
# 2595727   2019-12-20
# 2595728   2019-12-20
# 2595729   2019-12-20
# 2595730   2019-12-20
# 2595731   2019-12-20
# Name: Date, Length: 2595732, dtype: datetime64[ns]

# %%
CAMPAIGN_DESC_RAW['Start_date'] = start_date + pd.to_timedelta(CAMPAIGN_DESC_RAW['START_DAY'],unit = 'D')

# %%
CAMPAIGN_DESC_RAW['End_date'] = start_date + pd.to_timedelta(CAMPAIGN_DESC_RAW['END_DAY'],unit = 'D')

# %%
CAMPAIGN_DESC_RAW['Campaign_Duration'] = CAMPAIGN_DESC_RAW['END_DAY'] - CAMPAIGN_DESC_RAW['START_DAY']

# %%
COUPON_REDEMPT_RAW['Date'] = start_date + pd.to_timedelta(COUPON_REDEMPT_RAW['DAY'],unit = 'D')

# %%
TRANSACTION_RAW['Date'].max()
# Out:
# Timestamp('2020-12-12 00:00:00')

# %%
CAMPAIGN_DESC_RAW['End_date'].max()
# Out:
# Timestamp('2020-12-20 00:00:00')

# %%
COUPON_REDEMPT_RAW['Date'].max()
# Out:
# Timestamp('2020-12-05 00:00:00')

# %% [markdown]
# UnderStanding The Data

# %%
DEMOGRAPHIC_RAW.shape
# Out:
# (2500, 8)

# %%
DEMOGRAPHIC_RAW.columns
# Out:
# Index(['AGE_DESC', 'MARITAL_STATUS_CODE', 'INCOME_DESC', 'HOMEOWNER_DESC',
#        'HH_COMP_DESC', 'HOUSEHOLD_SIZE_DESC', 'KID_CATEGORY_DESC',
#        'HOUSEHOLD_KEY'],
#       dtype='object')

# %%
DEMOGRAPHIC_RAW.dtypes
# Out:
# AGE_DESC               object
# MARITAL_STATUS_CODE    object
# INCOME_DESC            object
# HOMEOWNER_DESC         object
# HH_COMP_DESC           object
# HOUSEHOLD_SIZE_DESC    object
# KID_CATEGORY_DESC      object
# HOUSEHOLD_KEY           int16
# dtype: object

# %%
DEMOGRAPHIC_RAW.isnull().sum()
# Out:
# AGE_DESC               0
# MARITAL_STATUS_CODE    0
# INCOME_DESC            0
# HOMEOWNER_DESC         0
# HH_COMP_DESC           0
# HOUSEHOLD_SIZE_DESC    0
# KID_CATEGORY_DESC      0
# HOUSEHOLD_KEY          0
# dtype: int64

# %%
DEMOGRAPHIC_RAW['AGE_DESC'].value_counts()
# Out:
# 45-54    901
# 35-44    594
# 25-34    445
# 65+      230
# 55-64    187
# 19-24    143
# Name: AGE_DESC, dtype: int64

# %%
DEMOGRAPHIC_RAW['HOUSEHOLD_SIZE_DESC'].value_counts()
# Out:
# 2     1004
# 1      783
# 3      338
# 5+     206
# 4      169
# Name: HOUSEHOLD_SIZE_DESC, dtype: int64

# %%
CAMPAIGN_DESC_RAW.shape
# Out:
# (30, 7)

# %%
CAMPAIGN_DESC_RAW.dtypes
# Out:
# DESCRIPTION                  object
# CAMPAIGN                       int8
# START_DAY                     int16
# END_DAY                       int16
# Start_date           datetime64[ns]
# End_date             datetime64[ns]
# Campaign_Duration             int16
# dtype: object

# %%
CAMPAIGN_DESC_RAW.value_counts()
# Out:
# DESCRIPTION  CAMPAIGN  START_DAY  END_DAY  Start_date  End_date    Campaign_Duration
# TypeA        8         412        460      2020-02-17  2020-04-05  48                   1
#              13        504        551      2020-05-19  2020-07-05  47                   1
# TypeC        20        615        685      2020-09-07  2020-11-16  70                   1
#              15        547        708      2020-07-01  2020-12-09  161                  1
#              14        531        596      2020-06-15  2020-08-19  65                   1
#              6         393        425      2020-01-29  2020-03-01  32                   1
#              3         356        412      2019-12-23  2020-02-17  56                   1
# TypeB        29        281        334      2019-10-09  2019-12-01  53                   1
#              28        259        320      2019-09-17  2019-11-17  61                   1
#              25        659        691      2020-10-21  2020-11-22  32                   1
#              24        659        719      2020-10-21  2020-12-20  60                   1
#              23        646        684      2020-10-08  2020-11-15  38                   1
#              22        624        656      2020-09-16  2020-10-18  32                   1
#              21        624        656      2020-09-16  2020-10-18  32                   1
#              19        603        635      2020-08-26  2020-09-27  32                   1
#              17        575        607      2020-07-29  2020-08-30  32                   1
#              16        561        593      2020-07-15  2020-08-16  32                   1
#              12        477        509      2020-04-22  2020-05-24  32                   1
#              11        477        523      2020-04-22  2020-06-07  46                   1
#              10        463        495      2020-04-08  2020-05-10  32                   1
#              9         435        467      2020-03-11  2020-04-12  32                   1
#              7         398        432      2020-02-03  2020-03-08  34                   1
#              5         377        411      2020-01-13  2020-02-16  34                   1
#              4         372        404      2020-01-08  2020-02-09  32                   1
#              2         351        383      2019-12-18  2020-01-19  32                   1
#              1         346        383      2019-12-13  2020-01-19  37                   1
# TypeA        30        323        369      2019-11-20  2020-01-05  46                   1
#              26        224        264      2019-08-13  2019-09-22  40                   1
#              18        587        642      2020-08-10  2020-10-04  55                   1
# TypeC        27        237        300      2019-08-26  2019-10-28  63                   1
# dtype: int64

# %%
CAMPAIGN_DESC_RAW['Campaign_Duration'].mean()
# Out:
# 46.6

# %%
plt.figure(figsize = (15,5))
sns.barplot(x = 'CAMPAIGN', y = 'Campaign_Duration', data = CAMPAIGN_DESC_RAW)
# Out:
# <AxesSubplot:xlabel='CAMPAIGN', ylabel='Campaign_Duration'>

# %%
CAMPAIGN_DESC_RAW.groupby('DESCRIPTION').aggregate({'CAMPAIGN':'count','Campaign_Duration':'mean'})
# Out:
#              CAMPAIGN  Campaign_Duration
# DESCRIPTION
# TypeA               5          47.200000
# TypeB              19          37.631579
# TypeC               6          74.500000

# %%
CAMPAIGN_DESC_RAW['Start_Month'] = CAMPAIGN_DESC_RAW['Start_date'].dt.strftime('%m')

# %%
CAMPAIGN_DESC_RAW['End_Month'] = CAMPAIGN_DESC_RAW['End_date'].dt.strftime('%m')

# %%
CAMPAIGN_DESC_RAW['Start_Year'] = CAMPAIGN_DESC_RAW['Start_date'].dt.strftime('%Y')

# %%
CAMPAIGN_DESC_RAW['End_Year'] = CAMPAIGN_DESC_RAW['End_date'].dt.strftime('%Y')

# %%
CAMPAIGN_DESC_RAW.head()
# Out:
#   DESCRIPTION  CAMPAIGN  START_DAY  END_DAY Start_date   End_date  \
# 0       TypeB        24        659      719 2020-10-21 2020-12-20
# 1       TypeC        15        547      708 2020-07-01 2020-12-09
# 2       TypeB        25        659      691 2020-10-21 2020-11-22
# 3       TypeC        20        615      685 2020-09-07 2020-11-16
# 4       TypeB        23        646      684 2020-10-08 2020-11-15
#
#    Campaign_Duration Start_Month End_Month Start_Year End_Year
# 0                 60          10        12       2020     2020
# 1                161          07        12       2020     2020
# 2                 32          10        11       2020     2020
# 3                 70          09        11       2020     2020
# 4                 38          10        11       2020     2020

# %%
CAMPAIGN_RAW.shape
# Out:
# (7208, 3)

# %%
CAMPAIGN_RAW
# Out:
#      DESCRIPTION  HOUSEHOLD_KEY  CAMPAIGN
# 0          TypeA             17        26
# 1          TypeA             27        26
# 2          TypeA            212        26
# 3          TypeA            208        26
# 4          TypeA            192        26
# ...          ...            ...       ...
# 7203       TypeC           1803        15
# 7204       TypeC           1082        15
# 7205       TypeC            942        15
# 7206       TypeC            855        15
# 7207       TypeC            334        15
#
# [7208 rows x 3 columns]

# %%
CAMPAIGN_RAW['HOUSEHOLD_KEY'].nunique()
# Out:
# 1584

# %%
TRANSACTION_RAW['HOUSEHOLD_KEY'].nunique()
# Out:
# 2500

# %%
CAMPAIGN_RAW.groupby('HOUSEHOLD_KEY')['CAMPAIGN'].count()
# Out:
# HOUSEHOLD_KEY
# 1       8
# 2       1
# 3       3
# 4       1
# 6       4
#        ..
# 2496    5
# 2497    3
# 2498    6
# 2499    2
# 2500    8
# Name: CAMPAIGN, Length: 1584, dtype: int64

# %%
CAMPAIGN_RAW.groupby('HOUSEHOLD_KEY').aggregate({'CAMPAIGN':'count'})
# Out:
#                CAMPAIGN
# HOUSEHOLD_KEY
# 1                     8
# 2                     1
# 3                     3
# 4                     1
# 6                     4
# ...                 ...
# 2496                  5
# 2497                  3
# 2498                  6
# 2499                  2
# 2500                  8
#
# [1584 rows x 1 columns]

# %%
plt.figure(figsize=(15,5))
CAMPAIGN_RAW.groupby('CAMPAIGN')['HOUSEHOLD_KEY'].count().plot.bar()
plt.ylabel('No of Household Reached To')
# Out:
# Text(0, 0.5, 'No of Household Reached To')

# %%
COUPON_RAW.shape
# Out:
# (124548, 3)

# %%
COUPON_RAW.dtypes
# Out:
# COUPON_UPC    int64
# PRODUCT_ID    int32
# CAMPAIGN       int8
# dtype: object

# %%
COUPON_RAW['COUPON_UPC'].nunique()
# Out:
# 1135

# %%
COUPON_GIVEN = COUPON_RAW.groupby('CAMPAIGN').aggregate(Total_Product = ('PRODUCT_ID','nunique'),
                                                        Total_Coupon_given = ('COUPON_UPC','nunique'))

# %%
COUPON_RAW.groupby('CAMPAIGN').aggregate({'PRODUCT_ID':'nunique','COUPON_UPC':'nunique'})
# Out:
#           PRODUCT_ID  COUPON_UPC
# CAMPAIGN
# 1                383          11
# 2                301          16
# 3                506          34
# 4                200          12
# 5                443          11
# 6                 18           1
# 7                259           8
# 8              17178         209
# 9                825          18
# 10               393          14
# 11               278          13
# 12               620          15
# 13             35616         207
# 14               714          26
# 15                55           2
# 16              1025          13
# 17               713          19
# 18             35513         209
# 19               375          11
# 20               609          24
# 21               242          16
# 22              1917          21
# 23               767          18
# 24              1887           2
# 25               826          17
# 26              3396         181
# 27               632          27
# 28               535          28
# 29               689          33
# 30              3205         181

# %%
COUPON_GIVEN
# Out:
#           Total_Product  Total_Coupon_given
# CAMPAIGN
# 1                   383                  11
# 2                   301                  16
# 3                   506                  34
# 4                   200                  12
# 5                   443                  11
# 6                    18                   1
# 7                   259                   8
# 8                 17178                 209
# 9                   825                  18
# 10                  393                  14
# 11                  278                  13
# 12                  620                  15
# 13                35616                 207
# 14                  714                  26
# 15                   55                   2
# 16                 1025                  13
# 17                  713                  19
# 18                35513                 209
# 19                  375                  11
# 20                  609                  24
# 21                  242                  16
# 22                 1917                  21
# 23                  767                  18
# 24                 1887                   2
# 25                  826                  17
# 26                 3396                 181
# 27                  632                  27
# 28                  535                  28
# 29                  689                  33
# 30                 3205                 181

# %%
COUPON_GIVEN = COUPON_GIVEN.merge(right = CAMPAIGN_DESC_RAW, on = 'CAMPAIGN', how='left')

# %%
COUPON_GIVEN.head(10)
# Out:
#    CAMPAIGN  Total_Product  Total_Coupon_given DESCRIPTION  START_DAY  \
# 0         1            383                  11       TypeB        346
# 1         2            301                  16       TypeB        351
# 2         3            506                  34       TypeC        356
# 3         4            200                  12       TypeB        372
# 4         5            443                  11       TypeB        377
# 5         6             18                   1       TypeC        393
# 6         7            259                   8       TypeB        398
# 7         8          17178                 209       TypeA        412
# 8         9            825                  18       TypeB        435
# 9        10            393                  14       TypeB        463
#
#    END_DAY Start_date   End_date  Campaign_Duration Start_Month End_Month  \
# 0      383 2019-12-13 2020-01-19                 37          12        01
# 1      383 2019-12-18 2020-01-19                 32          12        01
# 2      412 2019-12-23 2020-02-17                 56          12        02
# 3      404 2020-01-08 2020-02-09                 32          01        02
# 4      411 2020-01-13 2020-02-16                 34          01        02
# 5      425 2020-01-29 2020-03-01                 32          01        03
# 6      432 2020-02-03 2020-03-08                 34          02        03
# 7      460 2020-02-17 2020-04-05                 48          02        04
# 8      467 2020-03-11 2020-04-12                 32          03        04
# 9      495 2020-04-08 2020-05-10                 32          04        05
#
#   Start_Year End_Year
# 0       2019     2020
# 1       2019     2020
# 2       2019     2020
# 3       2020     2020
# 4       2020     2020
# 5       2020     2020
# 6       2020     2020
# 7       2020     2020
# 8       2020     2020
# 9       2020     2020

# %%
COUPON_GIVEN.sort_values(by = 'Total_Product',ascending = False).head(10)
# Out:
#     CAMPAIGN  Total_Product  Total_Coupon_given DESCRIPTION  START_DAY  \
# 12        13          35616                 207       TypeA        504
# 17        18          35513                 209       TypeA        587
# 7          8          17178                 209       TypeA        412
# 25        26           3396                 181       TypeA        224
# 29        30           3205                 181       TypeA        323
# 21        22           1917                  21       TypeB        624
# 23        24           1887                   2       TypeB        659
# 15        16           1025                  13       TypeB        561
# 24        25            826                  17       TypeB        659
# 8          9            825                  18       TypeB        435
#
#     END_DAY Start_date   End_date  Campaign_Duration Start_Month End_Month  \
# 12      551 2020-05-19 2020-07-05                 47          05        07
# 17      642 2020-08-10 2020-10-04                 55          08        10
# 7       460 2020-02-17 2020-04-05                 48          02        04
# 25      264 2019-08-13 2019-09-22                 40          08        09
# 29      369 2019-11-20 2020-01-05                 46          11        01
# 21      656 2020-09-16 2020-10-18                 32          09        10
# 23      719 2020-10-21 2020-12-20                 60          10        12
# 15      593 2020-07-15 2020-08-16                 32          07        08
# 24      691 2020-10-21 2020-11-22                 32          10        11
# 8       467 2020-03-11 2020-04-12                 32          03        04
#
#    Start_Year End_Year
# 12       2020     2020
# 17       2020     2020
# 7        2020     2020
# 25       2019     2019
# 29       2019     2020
# 21       2020     2020
# 23       2020     2020
# 15       2020     2020
# 24       2020     2020
# 8        2020     2020

# %%
COUPON_GIVEN.columns
# Out:
# Index(['CAMPAIGN', 'Total_Product', 'Total_Coupon_given', 'DESCRIPTION',
#        'START_DAY', 'END_DAY', 'Start_date', 'End_date', 'Campaign_Duration',
#        'Start_Month', 'End_Month', 'Start_Year', 'End_Year'],
#       dtype='object')

# %%
COUPON_GIVEN.loc[:,('CAMPAIGN','Total_Product','Total_Coupon_given','Start_Month','End_Month','Start_Year','End_Year','DESCRIPTION','Campaign_Duration')].sort_values(by = 'Total_Product',
                                                                                                                                              ascending = False).head(10)
# Out:
#     CAMPAIGN  Total_Product  Total_Coupon_given Start_Month End_Month  \
# 12        13          35616                 207          05        07
# 17        18          35513                 209          08        10
# 7          8          17178                 209          02        04
# 25        26           3396                 181          08        09
# 29        30           3205                 181          11        01
# 21        22           1917                  21          09        10
# 23        24           1887                   2          10        12
# 15        16           1025                  13          07        08
# 24        25            826                  17          10        11
# 8          9            825                  18          03        04
#
#    Start_Year End_Year DESCRIPTION  Campaign_Duration
# 12       2020     2020       TypeA                 47
# 17       2020     2020       TypeA                 55
# 7        2020     2020       TypeA                 48
# 25       2019     2019       TypeA                 40
# 29       2019     2020       TypeA                 46
# 21       2020     2020       TypeB                 32
# 23       2020     2020       TypeB                 60
# 15       2020     2020       TypeB                 32
# 24       2020     2020       TypeB                 32
# 8        2020     2020       TypeB                 32

# %%
Coupon_Product = COUPON_RAW.merge(right = PRODUCT_RAW, on = 'PRODUCT_ID', how = 'left')

# %%
Coupon_Product.head()
# Out:
#     COUPON_UPC  PRODUCT_ID  CAMPAIGN  MANUFACTURER DEPARTMENT     BRAND  \
# 0  10000089061       27160         4            69    GROCERY   Private
# 1  10000089064       27754         9            69    GROCERY   Private
# 2  10000089073       28897        12            69    GROCERY   Private
# 3  51800009050       28919        28           236    GROCERY  National
# 4  52100000076       28929        25           317    GROCERY  National
#
#              COMMODITY_DESC              SUB_COMMODITY_DESC  \
# 0            SHORTENING/OIL             VEGETABLE/SALAD OIL
# 1    FRZN VEGETABLE/VEG DSH  FRZN BAGGED VEGETABLES - PLAIN
# 2                      EGGS                  EGGS - X-LARGE
# 3  REFRGRATD DOUGH PRODUCTS       REFRIGERATED COOKIES-CHUB
# 4                    CHEESE                   STRING CHEESE
#
#   CURR_SIZE_OF_PRODUCT
# 0                48 OZ
# 1                16 OZ
# 2           A D   1 DZ
# 3              16.5 OZ
# 4           AB    8 OZ

# %%
Coupon_Product.isnull().sum()
# Out:
# COUPON_UPC              0
# PRODUCT_ID              0
# CAMPAIGN                0
# MANUFACTURER            0
# DEPARTMENT              0
# BRAND                   0
# COMMODITY_DESC          0
# SUB_COMMODITY_DESC      0
# CURR_SIZE_OF_PRODUCT    0
# dtype: int64

# %% [markdown]
# **Top 10 product on which the Coupon has been applied**

# %%
Coupon_Product['COMMODITY_DESC'].value_counts().head(10)
# Out:
# HAIR CARE PRODUCTS        6261
# MAKEUP AND TREATMENT      5585
# FRZN MEAT/MEAT DINNERS    4893
# FROZEN PIZZA              3658
# BEEF                      3314
# ICE CREAM/MILK/SHERBTS    3257
# CHEESE                    3146
# YOGURT                    2460
# ORAL HYGIENE PRODUCTS     2437
# LUNCHMEAT                 2425
# Name: COMMODITY_DESC, dtype: int64

# %% [markdown]
# **Most prominent products among coupons created are bathroom products such as hair care and makeup.**

# %%
COUPON_REDEMPT_RAW.shape
# Out:
# (2318, 5)

# %%
COUPON_REDEMPT_RAW.columns
# Out:
# Index(['HOUSEHOLD_KEY', 'DAY', 'COUPON_UPC', 'CAMPAIGN', 'Date'], dtype='object')

# %%
COUPON_REDEMPT_RAW['COUPON_UPC'].nunique()
# Out:
# 556

# %% [markdown]
# **Only 556 Coupon has been used out of 1135**

# %%
COUPON_REDEMPT_RAW.groupby('CAMPAIGN').agg(total_coupon_reedm=('COUPON_UPC','nunique')).sort_values(by='total_coupon_reedm',ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='CAMPAIGN'>

# %%
Coupon_redeem = COUPON_REDEMPT_RAW.groupby('CAMPAIGN').agg(total_coupon_reedm=('COUPON_UPC','nunique'))

# %%
Coupon_redeem.head()
# Out:
#           total_coupon_reedm
# CAMPAIGN
# 1                          1
# 2                          4
# 3                          2
# 4                          6
# 5                          5

# %%
Coupon_redeem.sort_values(by = 'total_coupon_reedm',ascending=False)
# Out:
#           total_coupon_reedm
# CAMPAIGN
# 13                       129
# 18                       121
# 8                        105
# 26                        53
# 30                        41
# 29                        17
# 23                        16
# 25                        15
# 20                        15
# 9                         14
# 14                        14
# 17                        13
# 22                        12
# 12                        11
# 16                        10
# 19                         9
# 10                         7
# 11                         6
# 4                          6
# 21                         5
# 7                          5
# 5                          5
# 2                          4
# 15                         2
# 24                         2
# 3                          2
# 6                          1
# 27                         1
# 28                         1
# 1                          1

# %%
COUPON_GIVEN.head()
# Out:
#    CAMPAIGN  Total_Product  Total_Coupon_given DESCRIPTION  START_DAY  \
# 0         1            383                  11       TypeB        346
# 1         2            301                  16       TypeB        351
# 2         3            506                  34       TypeC        356
# 3         4            200                  12       TypeB        372
# 4         5            443                  11       TypeB        377
#
#    END_DAY Start_date   End_date  Campaign_Duration Start_Month End_Month  \
# 0      383 2019-12-13 2020-01-19                 37          12        01
# 1      383 2019-12-18 2020-01-19                 32          12        01
# 2      412 2019-12-23 2020-02-17                 56          12        02
# 3      404 2020-01-08 2020-02-09                 32          01        02
# 4      411 2020-01-13 2020-02-16                 34          01        02
#
#   Start_Year End_Year
# 0       2019     2020
# 1       2019     2020
# 2       2019     2020
# 3       2020     2020
# 4       2020     2020

# %%
Coupon_redeem.head()
# Out:
#           total_coupon_reedm
# CAMPAIGN
# 1                          1
# 2                          4
# 3                          2
# 4                          6
# 5                          5

# %%
Coupon_redeem = Coupon_redeem.merge(right = COUPON_GIVEN,on='CAMPAIGN',how='left')

# %%
Coupon_redeem.head()
# Out:
#    CAMPAIGN  total_coupon_reedm  Total_Product  Total_Coupon_given  \
# 0         1                   1            383                  11
# 1         2                   4            301                  16
# 2         3                   2            506                  34
# 3         4                   6            200                  12
# 4         5                   5            443                  11
#
#   DESCRIPTION  START_DAY  END_DAY Start_date   End_date  Campaign_Duration  \
# 0       TypeB        346      383 2019-12-13 2020-01-19                 37
# 1       TypeB        351      383 2019-12-18 2020-01-19                 32
# 2       TypeC        356      412 2019-12-23 2020-02-17                 56
# 3       TypeB        372      404 2020-01-08 2020-02-09                 32
# 4       TypeB        377      411 2020-01-13 2020-02-16                 34
#
#   Start_Month End_Month Start_Year End_Year
# 0          12        01       2019     2020
# 1          12        01       2019     2020
# 2          12        02       2019     2020
# 3          01        02       2020     2020
# 4          01        02       2020     2020

# %%
Coupon_redeem['Coupon_redeem_rate']=(Coupon_redeem['total_coupon_reedm']/Coupon_redeem['Total_Coupon_given'])*100

# %%
Coupon_redeem.head().sort_values(by = 'Coupon_redeem_rate',ascending = False)
# Out:
#    CAMPAIGN  total_coupon_reedm  Total_Product  Total_Coupon_given  \
# 3         4                   6            200                  12
# 4         5                   5            443                  11
# 1         2                   4            301                  16
# 0         1                   1            383                  11
# 2         3                   2            506                  34
#
#   DESCRIPTION  START_DAY  END_DAY Start_date   End_date  Campaign_Duration  \
# 3       TypeB        372      404 2020-01-08 2020-02-09                 32
# 4       TypeB        377      411 2020-01-13 2020-02-16                 34
# 1       TypeB        351      383 2019-12-18 2020-01-19                 32
# 0       TypeB        346      383 2019-12-13 2020-01-19                 37
# 2       TypeC        356      412 2019-12-23 2020-02-17                 56
#
#   Start_Month End_Month Start_Year End_Year  Coupon_redeem_rate
# 3          01        02       2020     2020           50.000000
# 4          01        02       2020     2020           45.454545
# 1          12        01       2019     2020           25.000000
# 0          12        01       2019     2020            9.090909
# 2          12        02       2019     2020            5.882353

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='CAMPAIGN',y='Coupon_redeem_rate',data=Coupon_redeem)
# Out:
# <AxesSubplot:xlabel='CAMPAIGN', ylabel='Coupon_redeem_rate'>

# %%
TRANSACTION_RAW.shape
# Out:
# (2595732, 13)

# %%
TRANSACTION_RAW.columns
# Out:
# Index(['HOUSEHOLD_KEY', 'BASKET_ID', 'DAY', 'PRODUCT_ID', 'QUANTITY',
#        'SALES_VALUE', 'STORE_ID', 'RETAIL_DISC', 'TRANS_TIME', 'WEEK_NO',
#        'COUPON_DISC', 'COUPON_MATCH_DISC', 'Date'],
#       dtype='object')

# %%
TRANSACTION_RAW.isnull().sum()
# Out:
# HOUSEHOLD_KEY        0
# BASKET_ID            0
# DAY                  0
# PRODUCT_ID           0
# QUANTITY             0
# SALES_VALUE          0
# STORE_ID             0
# RETAIL_DISC          0
# TRANS_TIME           0
# WEEK_NO              0
# COUPON_DISC          0
# COUPON_MATCH_DISC    0
# Date                 0
# dtype: int64

# %%
TRANSACTION_RAW['BASKET_ID'].count()
# Out:
# 2595732

# %%
TRANSACTION_RAW['BASKET_ID'].nunique()
# Out:
# 276484

# %%
TRANSACTION_RAW['HOUSEHOLD_KEY'].nunique()
# Out:
# 2500

# %%
trnx_bucket =TRANSACTION_RAW.groupby('BASKET_ID').aggregate({'SALES_VALUE':'sum','COUPON_DISC':'sum','COUPON_MATCH_DISC':'sum'})

# %%
trnx_bucket.head()
# Out:
#              SALES_VALUE  COUPON_DISC  COUPON_MATCH_DISC
# BASKET_ID
# 26984851472         5.91            0                  0
# 26984851516        12.43            0                  0
# 26984896261        11.37            0                  0
# 26984905972         2.55            0                  0
# 26984945254         3.53            0                  0

# %%
trnx_bucket['Use_coupon'] = trnx_bucket['COUPON_DISC']!=0

# %%
trnx_bucket['Use_coupon'].value_counts()
# Out:
# False    260812
# True      15672
# Name: Use_coupon, dtype: int64

# %%
trnx_bucket.sort_values('SALES_VALUE',ascending=False).head(10)
# Out:
#              SALES_VALUE  COUPON_DISC  COUPON_MATCH_DISC  Use_coupon
# BASKET_ID
# 32006114302       961.49            0                  0       False
# 40387571385       681.58            0                  0       False
# 33347880492       552.92           -3                  0        True
# 32505140858       545.17            0                  0       False
# 30983766334       545.07            0                  0       False
# 35638473903       543.83            0                  0       False
# 34267311742       518.01            0                  0       False
# 30515165970       508.58            0                  0       False
# 32187143334       499.99            0                  0       False
# 41560297395       497.02           -3                  0        True

# %%
trnx_bucket.head(10)
# Out:
#              SALES_VALUE  COUPON_DISC  COUPON_MATCH_DISC  Use_coupon
# BASKET_ID
# 26984851472         5.91            0                  0       False
# 26984851516        12.43            0                  0       False
# 26984896261        11.37            0                  0       False
# 26984905972         2.55            0                  0       False
# 26984945254         3.53            0                  0       False
# 26984951769         5.79            0                  0       False
# 26985025264        44.78            0                  0       False
# 26985040735       139.22            0                  0       False
# 26985052379         0.99            0                  0       False
# 26985165432         0.00            0                  0       False

# %%
round(trnx_bucket['SALES_VALUE'].mean(),2)
# Out:
# 29.14

# %% [markdown]
# The average basket value is $29.14

# %%
plt.figure(figsize=(25,5))
sns.boxplot(x=trnx_bucket['SALES_VALUE'])
plt.title('Basket value boxplot', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Basket value boxplot')

# %%
trnx_bucket.groupby('Use_coupon').aggregate( sales_mean=('SALES_VALUE','mean'),
                                             COUPON_DISC_mean =('COUPON_DISC','mean'),
                                             COUPON_MATCH_DISC=('COUPON_MATCH_DISC','mean'),
                                             No_coupon  =('SALES_VALUE','count'))
# Out:
#             sales_mean  COUPON_DISC_mean  COUPON_MATCH_DISC  No_coupon
# Use_coupon
# False        26.795021          0.000000          -0.000019     260812
# True         68.210833         -2.986536          -0.426748      15672

# %% [markdown]
# The average basket value without a coupon is $26.79.
#
# The average basket value with a coupon is $68.21.
#
# The average discount generated by coupons is $2.98.

# %% [markdown]
# **It shows that customeer purchase more product when coupon is given to them**

# %%
trnx_desc = TRANSACTION_RAW.merge(right= trnx_bucket,on='BASKET_ID',how='left')

# %%
trnx_desc.head()
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE_x  \
# 0           2375  26984851472    1     1004906         1           1.39
# 1           2375  26984851472    1     1033142         1           0.82
# 2           2375  26984851472    1     1036325         1           0.99
# 3           2375  26984851472    1     1082185         1           1.21
# 4           2375  26984851472    1     8160430         1           1.50
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC_x  \
# 0       364        -0.60        1631        1              0
# 1       364         0.00        1631        1              0
# 2       364        -0.30        1631        1              0
# 3       364         0.00        1631        1              0
# 4       364        -0.39        1631        1              0
#
#    COUPON_MATCH_DISC_x       Date  SALES_VALUE_y  COUPON_DISC_y  \
# 0                    0 2019-01-02           5.91              0
# 1                    0 2019-01-02           5.91              0
# 2                    0 2019-01-02           5.91              0
# 3                    0 2019-01-02           5.91              0
# 4                    0 2019-01-02           5.91              0
#
#    COUPON_MATCH_DISC_y  Use_coupon
# 0                    0       False
# 1                    0       False
# 2                    0       False
# 3                    0       False
# 4                    0       False

# %%
trnx_desc= trnx_desc.merge(right=PRODUCT_RAW,on='PRODUCT_ID',how='left')

# %%
trnx_desc.head(5)
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE_x  \
# 0           2375  26984851472    1     1004906         1           1.39
# 1           2375  26984851472    1     1033142         1           0.82
# 2           2375  26984851472    1     1036325         1           0.99
# 3           2375  26984851472    1     1082185         1           1.21
# 4           2375  26984851472    1     8160430         1           1.50
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  ...  SALES_VALUE_y  \
# 0       364        -0.60        1631        1  ...           5.91
# 1       364         0.00        1631        1  ...           5.91
# 2       364        -0.30        1631        1  ...           5.91
# 3       364         0.00        1631        1  ...           5.91
# 4       364        -0.39        1631        1  ...           5.91
#
#    COUPON_DISC_y COUPON_MATCH_DISC_y  Use_coupon  MANUFACTURER  DEPARTMENT  \
# 0              0                   0       False            69     PRODUCE
# 1              0                   0       False             2     PRODUCE
# 2              0                   0       False            69     PRODUCE
# 3              0                   0       False             2     PRODUCE
# 4              0                   0       False            69     PRODUCE
#
#       BRAND               COMMODITY_DESC          SUB_COMMODITY_DESC  \
# 0   Private                     POTATOES  POTATOES RUSSET (BULK&BAG)
# 1  National                       ONIONS     ONIONS SWEET (BULK&BAG)
# 2   Private      VEGETABLES - ALL OTHERS                      CELERY
# 3  National               TROPICAL FRUIT                     BANANAS
# 4   Private  ORGANICS FRUIT & VEGETABLES             ORGANIC CARROTS
#
#   CURR_SIZE_OF_PRODUCT
# 0                 5 LB
# 1                40 LB
# 2
# 3                40 LB
# 4                 1 LB
#
# [5 rows x 23 columns]

# %%
trnx_desc.drop(['SALES_VALUE_y','COUPON_DISC_y','COUPON_MATCH_DISC_y'],axis=1,inplace=True)

# %%
trnx_desc.head(10)
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE_x  \
# 0           2375  26984851472    1     1004906         1           1.39
# 1           2375  26984851472    1     1033142         1           0.82
# 2           2375  26984851472    1     1036325         1           0.99
# 3           2375  26984851472    1     1082185         1           1.21
# 4           2375  26984851472    1     8160430         1           1.50
# 5           2375  26984851516    1      826249         2           1.98
# 6           2375  26984851516    1     1043142         1           1.57
# 7           2375  26984851516    1     1085983         1           2.99
# 8           2375  26984851516    1     1102651         1           1.89
# 9           2375  26984851516    1     6423775         1           2.00
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC_x  \
# 0       364        -0.60        1631        1              0
# 1       364         0.00        1631        1              0
# 2       364        -0.30        1631        1              0
# 3       364         0.00        1631        1              0
# 4       364        -0.39        1631        1              0
# 5       364        -0.60        1642        1              0
# 6       364        -0.68        1642        1              0
# 7       364        -0.40        1642        1              0
# 8       364         0.00        1642        1              0
# 9       364        -0.79        1642        1              0
#
#    COUPON_MATCH_DISC_x       Date  Use_coupon  MANUFACTURER DEPARTMENT  \
# 0                    0 2019-01-02       False            69    PRODUCE
# 1                    0 2019-01-02       False             2    PRODUCE
# 2                    0 2019-01-02       False            69    PRODUCE
# 3                    0 2019-01-02       False             2    PRODUCE
# 4                    0 2019-01-02       False            69    PRODUCE
# 5                    0 2019-01-02       False            69    GROCERY
# 6                    0 2019-01-02       False           321    DRUG GM
# 7                    0 2019-01-02       False           586    GROCERY
# 8                    0 2019-01-02       False          1266    GROCERY
# 9                    0 2019-01-02       False           586    GROCERY
#
#       BRAND               COMMODITY_DESC           SUB_COMMODITY_DESC  \
# 0   Private                     POTATOES   POTATOES RUSSET (BULK&BAG)
# 1  National                       ONIONS      ONIONS SWEET (BULK&BAG)
# 2   Private      VEGETABLES - ALL OTHERS                       CELERY
# 3  National               TROPICAL FRUIT                      BANANAS
# 4   Private  ORGANICS FRUIT & VEGETABLES              ORGANIC CARROTS
# 5   Private       BAKED BREAD/BUNS/ROLLS               HAMBURGER BUNS
# 6  National              BROOMS AND MOPS      SPONGES: BATH HOUSEHOLD
# 7  National                COOKIES/CONES  TRAY PACK/CHOC CHIP COOKIES
# 8  National           PNT BTR/JELLY/JAMS                PEANUT BUTTER
# 9  National                COOKIES/CONES              GRAHAM CRACKERS
#
#   CURR_SIZE_OF_PRODUCT
# 0                 5 LB
# 1                40 LB
# 2
# 3                40 LB
# 4                 1 LB
# 5                12 OZ
# 6
# 7                18 OZ
# 8                12 OZ
# 9                11 OZ

# %%
COMMODITY_Coupon = trnx_desc.groupby('COMMODITY_DESC').aggregate(total_quantity=('QUANTITY','count'),
                                    Use_coupon=('Use_coupon','sum'),
                                    Coupon=('COUPON_DISC_x','sum'))

# %%
COMMODITY_Coupon
# Out:
#                                 total_quantity  Use_coupon   Coupon
# COMMODITY_DESC
#                                           7839        6019 -10596.0
# (CORP USE ONLY)                             61           5      0.0
# ADULT INCONTINENCE                         553          87    -37.0
# AIR CARE                                  5556        1320   -929.0
# ANALGESICS                                4769         692    -13.0
# ...                                        ...         ...      ...
# WAREHOUSE SNACKS                          9050        1287   -102.0
# WATCHES/CALCULATORS/LOBBY                   43           2      0.0
# WATER                                     2298         155      0.0
# WATER - CARBONATED/FLVRD DRINK           21232        2295   -130.0
# YOGURT                                   44697        7924   -710.0
#
# [308 rows x 3 columns]

# %%
COMMODITY_Coupon['Coupon%']=round((COMMODITY_Coupon['Use_coupon']/COMMODITY_Coupon['total_quantity'])*100,2)

# %%
COMMODITY_Coupon.sort_values('Coupon%',ascending=False).head(30)
# Out:
#                                 total_quantity  Use_coupon   Coupon  Coupon%
# COMMODITY_DESC
#                                           7839        6019 -10596.0    76.78
# BABY FOODS                               20356        5648   -349.0    27.75
# RESTRICTED DIET                             51          13      0.0    25.49
# DIAPERS & DISPOSABLES                     5008        1216  -1110.0    24.28
# AIR CARE                                  5556        1320   -929.0    23.76
# FRZN SEAFOOD                                64          15      0.0    23.44
# BULK FOODS                                   9           2      0.0    22.22
# BABY HBC                                  4626        1020   -325.0    22.05
# FRZN BREAKFAST FOODS                     10595        2286   -421.0    21.58
# SMOKING CESSATIONS                          79          17      0.0    21.52
# FROZEN - BOXED(GROCERY)                    971         208    -40.0    21.42
# HOUSEHOLD CLEANG NEEDS                   10460        2221   -665.0    21.23
# RICE CAKES                                1622         333     -6.0    20.53
# CAT LITTER                                3272         665   -202.0    20.32
# REFRGRATD DOUGH PRODUCTS                 18960        3848   -948.0    20.30
# VITAMINS                                  2426         489   -211.0    20.16
# LAUNDRY ADDITIVES                         4979         993   -148.0    19.94
# FROZEN BREAD/DOUGH                        7912        1567   -432.0    19.81
# FACIAL TISS/DNR NAPKIN                    7800        1527   -130.0    19.58
# PICKLE/RELISH/PKLD VEG                    7071        1381   -351.0    19.53
# DOG FOODS                                12093        2351   -786.0    19.44
# FRUIT - SHELF STABLE                     21536        4175   -172.0    19.39
# CONVENIENT BRKFST/WHLSM SNACKS           22547        4358   -608.0    19.33
# DISHWASH DETERGENTS                       6942        1330   -324.0    19.16
# FRZN VEGETABLE/VEG DSH                   22564        4271   -249.0    18.93
# HAND/BODY/FACIAL PRODUCTS                 3441         643   -197.0    18.69
# CAT FOOD                                 16210        3015   -454.0    18.60
# BABYFOOD                                   475          88     -6.0    18.53
# ORAL HYGIENE PRODUCTS                    10324        1888   -659.0    18.29
# MOLASSES/SYRUP/PANCAKE MIXS               5443         994   -106.0    18.26

# %% [markdown]
# **While the most prominents products for which coupons are created are haircare and makeup products, coupons are mostly used on drinks, cigarettes, diapers, etc. Bathroom products are not even among the top 10**

# %%
TRANSACTION_RAW.groupby(['HOUSEHOLD_KEY','WEEK_NO','DAY']).aggregate({'SALES_VALUE':'sum','RETAIL_DISC':'sum',
                                                           'COUPON_DISC' :'sum','COUPON_MATCH_DISC':'sum'})
# Out:
#                            SALES_VALUE  RETAIL_DISC  COUPON_DISC  \
# HOUSEHOLD_KEY WEEK_NO DAY
# 1             8       51         78.66       -16.54           -1
#               10      67         41.10        -8.59            0
#               13      88         26.90        -6.72            0
#               14      94         63.43       -11.08           -2
#               15      101        53.45       -16.42            0
# ...                                ...          ...          ...
# 2500          100     695        57.68       -14.85           -2
#                       698        50.54       -14.72           -2
#               101     704        73.65       -19.79           -2
#               102     706        13.95        -0.42            0
#                       708        45.12       -15.99           -1
#
#                            COUPON_MATCH_DISC
# HOUSEHOLD_KEY WEEK_NO DAY
# 1             8       51                   0
#               10      67                   0
#               13      88                   0
#               14      94                  -1
#               15      101                  0
# ...                                      ...
# 2500          100     695                  0
#                       698                  0
#               101     704                  0
#               102     706                  0
#                       708                  0
#
# [225533 rows x 4 columns]

# %%
TRANSACTION_RAW.head()
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           2375  26984851472    1     1004906         1         1.39
# 1           2375  26984851472    1     1033142         1         0.82
# 2           2375  26984851472    1     1036325         1         0.99
# 3           2375  26984851472    1     1082185         1         1.21
# 4           2375  26984851472    1     8160430         1         1.50
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC  \
# 0       364        -0.60        1631        1            0                  0
# 1       364         0.00        1631        1            0                  0
# 2       364        -0.30        1631        1            0                  0
# 3       364         0.00        1631        1            0                  0
# 4       364        -0.39        1631        1            0                  0
#
#         Date
# 0 2019-01-02
# 1 2019-01-02
# 2 2019-01-02
# 3 2019-01-02
# 4 2019-01-02

# %%
TRANSACTION_RAW.groupby(TRANSACTION_RAW['Date'].dt.year).aggregate({'SALES_VALUE':'sum','RETAIL_DISC':'sum',
                                                                   'COUPON_DISC':'sum'})
# Out:
#       SALES_VALUE  RETAIL_DISC  COUPON_DISC
# Date
# 2019   3636562.00   -639843.50     -18813.0
# 2020   4420901.08   -758491.34     -27992.0

# %% [markdown]
# **Sales Value increases as Retail Discount and Coupon Discount increases**

# %% [markdown]
# ***Droping the columns***

# %%
from datetime import datetime

# %%
CAMPAIGN_DESC_RAW.drop(['START_DAY','END_DAY'],axis=1,inplace=True)

# %%
CAMPAIGN_DESC_RAW.head()
# Out:
#   DESCRIPTION  CAMPAIGN Start_date   End_date  Campaign_Duration Start_Month  \
# 0       TypeB        24 2020-10-21 2020-12-20                 60          10
# 1       TypeC        15 2020-07-01 2020-12-09                161          07
# 2       TypeB        25 2020-10-21 2020-11-22                 32          10
# 3       TypeC        20 2020-09-07 2020-11-16                 70          09
# 4       TypeB        23 2020-10-08 2020-11-15                 38          10
#
#   End_Month Start_Year End_Year
# 0        12       2020     2020
# 1        12       2020     2020
# 2        11       2020     2020
# 3        11       2020     2020
# 4        11       2020     2020

# %%
CAMPAIGN_DESC_RAW['Start_date'] = pd.to_datetime(CAMPAIGN_DESC_RAW['Start_date']).apply(lambda x: x.date())

# %%
type(CAMPAIGN_DESC_RAW['Start_date'])
# Out:
# pandas.core.series.Series

# %%
CAMPAIGN_DESC_RAW['Start_date']
# Out:
# 0     2020-10-21
# 1     2020-07-01
# 2     2020-10-21
# 3     2020-09-07
# 4     2020-10-08
# 5     2020-09-16
# 6     2020-09-16
# 7     2020-08-10
# 8     2020-08-26
# 9     2020-07-29
# 10    2020-06-15
# 11    2020-07-15
# 12    2020-05-19
# 13    2020-04-22
# 14    2020-04-22
# 15    2020-04-08
# 16    2020-03-11
# 17    2020-02-17
# 18    2020-02-03
# 19    2020-01-29
# 20    2019-12-23
# 21    2020-01-13
# 22    2020-01-08
# 23    2019-12-13
# 24    2019-12-18
# 25    2019-11-20
# 26    2019-10-09
# 27    2019-09-17
# 28    2019-08-26
# 29    2019-08-13
# Name: Start_date, dtype: object

# %%
CAMPAIGN_DESC_RAW['End_date'] = pd.to_datetime(CAMPAIGN_DESC_RAW['End_date']).apply(lambda x: x.date())

# %%
type(CAMPAIGN_DESC_RAW['End_date'])
# Out:
# pandas.core.series.Series

# %%
CAMPAIGN_DESC_RAW['End_date']
# Out:
# 0     2020-12-20
# 1     2020-12-09
# 2     2020-11-22
# 3     2020-11-16
# 4     2020-11-15
# 5     2020-10-18
# 6     2020-10-18
# 7     2020-10-04
# 8     2020-09-27
# 9     2020-08-30
# 10    2020-08-19
# 11    2020-08-16
# 12    2020-07-05
# 13    2020-06-07
# 14    2020-05-24
# 15    2020-05-10
# 16    2020-04-12
# 17    2020-04-05
# 18    2020-03-08
# 19    2020-03-01
# 20    2020-02-17
# 21    2020-02-16
# 22    2020-02-09
# 23    2020-01-19
# 24    2020-01-19
# 25    2020-01-05
# 26    2019-12-01
# 27    2019-11-17
# 28    2019-10-28
# 29    2019-09-22
# Name: End_date, dtype: object

# %%
COUPON_REDEMPT_RAW.drop(['DAY'],axis=1,inplace=True)

# %%
COUPON_REDEMPT_RAW.head(3)
# Out:
#    HOUSEHOLD_KEY   COUPON_UPC  CAMPAIGN       Date
# 0              1  10000085364         8 2020-02-26
# 1              1  51700010076         8 2020-02-26
# 2              1  54200000033         8 2020-03-03

# %%
COUPON_REDEMPT_RAW['Date']=pd.to_datetime(COUPON_REDEMPT_RAW['Date']).apply(lambda x: x.date())

# %%
COUPON_REDEMPT_RAW.dtypes
# Out:
# HOUSEHOLD_KEY     int16
# COUPON_UPC        int64
# CAMPAIGN           int8
# Date             object
# dtype: object

# %%
TRANSACTION_RAW.drop(['DAY','WEEK_NO'],axis=1,inplace=True)

# %%
TRANSACTION_RAW.head()
# Out:
#    HOUSEHOLD_KEY    BASKET_ID  PRODUCT_ID  QUANTITY  SALES_VALUE  STORE_ID  \
# 0           2375  26984851472     1004906         1         1.39       364
# 1           2375  26984851472     1033142         1         0.82       364
# 2           2375  26984851472     1036325         1         0.99       364
# 3           2375  26984851472     1082185         1         1.21       364
# 4           2375  26984851472     8160430         1         1.50       364
#
#    RETAIL_DISC  TRANS_TIME  COUPON_DISC  COUPON_MATCH_DISC       Date
# 0        -0.60        1631            0                  0 2019-01-02
# 1         0.00        1631            0                  0 2019-01-02
# 2        -0.30        1631            0                  0 2019-01-02
# 3         0.00        1631            0                  0 2019-01-02
# 4        -0.39        1631            0                  0 2019-01-02

# %%
TRANSACTION_RAW['Date']=pd.to_datetime(TRANSACTION_RAW['Date']).apply(lambda x: x.date())

# %%
TRANSACTION_RAW.dtypes
# Out:
# HOUSEHOLD_KEY          int16
# BASKET_ID              int64
# PRODUCT_ID             int32
# QUANTITY               int32
# SALES_VALUE          float64
# STORE_ID               int32
# RETAIL_DISC          float64
# TRANS_TIME             int16
# COUPON_DISC             int8
# COUPON_MATCH_DISC       int8
# Date                  object
# dtype: object

# %% [markdown]
# **Now loading the table to DB**

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine import URL
import snowflake.connector as snowCtx
from snowflake.connector.pandas_tools import write_pandas
import pandas as pd
import getpass

# %%
conn = snowflake.connector.connect(
        user = 'EKANT02',
        ##password = getpass.getpass('Your Snowflake Password: ')
        password='Akant@1901',
        account = 'bcfkzvf-rd27110',
        database='Retail',
        warehouse='COMPUTE_WH',
        schema ='PUBLIC'
 )

# %%
cur=conn.cursor()

# %%
cur.execute(''' CREATE OR REPLACE TABLE COUPON_REDEMPT_NEW
(HOUSEHOLD_KEY NUMBER(38,0),
COUPON_UPC NUMBER(38,0),
CAMPAIGN NUMBER(38,0),
Date Date
)''')

# %%
cur.execute('''CREATE OR REPLACE TABLE TRANSACTION_NEW
(HOUSEHOLD_KEY NUMBER(38,0),
BASKET_ID NUMBER(38,0),
PRODUCT_ID NUMBER(38,0),
QUANTITY NUMBER(38,0),
SALES_VALUE FLOAT,
STORE_ID NUMBER(38,0),
RETAIL_DISC FLOAT,
TRANS_TIME NUMBER(38,0),
COUPON_DISC FLOAT,
COUPON_MATCH_DISC FLOAT,
Date Date
)
''')

# %%
cur.execute('''
CREATE OR REPLACE TABLE CAMPAIGN_DESC_NEW
(DESCRIPTION VARCHAR(10),
CAMPAIGN NUMBER(38,0),
Start_date date,
End_date  date,
Campaign_Duration NUMBER(38,0),
Start_month VARCHAR(10),
End_month VARCHAR(10),
Start_Year INT,
End_Year INT)''')

# %%
success, nchunks, nrows, _ = write_pandas(conn, CAMPAIGN_DESC_RAW,'CAMPAIGN_DESC_NEW',quote_identifiers=False)
print(str(success)+','+str(nchunks)+','+str(nrows))
# Out:
# True,1,30

# %%
success, nchunks, nrows, _ = write_pandas(conn, COUPON_REDEMPT_RAW,'COUPON_REDEMPT_NEW',quote_identifiers=False)
print(str(success)+','+str(nchunks)+','+str(nrows))
# Out:
# True,1,2318

# %%
success, nchunks, nrows, _ = write_pandas(conn,TRANSACTION_RAW ,'TRANSACTION_NEW',quote_identifiers=False)
print(str(success)+','+str(nchunks)+','+str(nrows))
# Out:
# True,1,2595732

# %%
cur.close()
conn.close()
